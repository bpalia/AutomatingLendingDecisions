# %% [markdown]
# # Lazy Prediction of Loan Grade Model

# %% [markdown]
# First, all the necessary libraries are imported.

# %%
import lazypredict
import pandas as pd
from imblearn.metrics import macro_averaged_mean_absolute_error
from helper_functions.custom_model import (
    reg_macro_averaged_mean_absolute_error,
)
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from helper_functions.ml_data_prep import (
    stratified_sample,
    X_y_spilt,
)
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# Computationally expensive and unable to execute classifiers and regressors are removed.

# %%
classifiers = lazypredict.Supervised.CLASSIFIERS
classifiers_to_remove = [
    "StackingClassifier",
    "CategoricalNB",
    "LabelPropagation",
    "LabelSpreading",
    "NuSVC",
    "SVC",
    "LinearSVC",
]
for model, _ in classifiers[:]:
    if model in classifiers_to_remove:
        classifiers.remove((model, _))

# %%
regressors = lazypredict.Supervised.REGRESSORS
regressors_to_remove = [
    "GammaRegressor",
    "QuantileRegressor",
    "GaussianProcessRegressor",
    "KernelRidge",
    "NuSVR",
    "SVR",
    "RandomForestRegressor",
    "ExtraTreesRegressor",
]
for model, _ in regressors[:]:
    if model in regressors_to_remove:
        regressors.remove((model, _))

# %% [markdown]
# Data loaded and splited. Training performed on balanced data. Only 25% of validation data is used.

# %%
drop_cols = ["sub_grade", "int_rate", "sub_grade_enc", "grade"]
X_train, y_train = (
    pd.read_pickle("./data/data_train_balanced_mod2.pkl")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="grade_enc")
)
X_val, y_val = (
    pd.read_pickle("./data/data_val_mod2.pkl")
    .pipe(stratified_sample, frac=0.25, col="sub_grade")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="grade_enc")
)
print(f"Number of training instances {X_train.shape[0]}")
print(f"Number of validation instances {X_val.shape[0]}")
print("Target counts for validation:")
print(y_val.value_counts())
# Out:
# Number of training instances 53935
# Number of validation instances 59660
# Target counts for validation:
# grade_enc
# 1    17682
# 2    16066
# 0    14946
# 3     8480
# 4     2010
# 5      402
# 6       74
# Name: count, dtype: int64

# %% [markdown]
# A number of different classifiers and regressors are trained and evaluated. Macro averaged mean absolute error is used to compare classifiers and regressors. This metric accounts for class order.

# %%
clf = LazyClassifier(
    random_state=42, custom_metric=macro_averaged_mean_absolute_error
)
clf_models, _ = clf.fit(X_train, X_val, y_train, y_val)
clf_models
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#  95%|█████████▌| 21/22 [01:33<00:03,  3.62s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001995 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2751
# [LightGBM] [Info] Number of data points in the train set: 53935, number of used features: 31
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# [LightGBM] [Info] Start training from score -1.945910
# 100%|██████████| 22/22 [01:36<00:00,  4.38s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# XGBClassifier                      0.42               0.36    None      0.43
# LGBMClassifier                     0.43               0.36    None      0.44
# LogisticRegression                 0.42               0.36    None      0.43
# LinearDiscriminantAnalysis         0.39               0.35    None      0.40
# AdaBoostClassifier                 0.40               0.35    None      0.41
# CalibratedClassifierCV             0.38               0.35    None      0.37
# ExtraTreesClassifier               0.41               0.35    None      0.41
# BernoulliNB                        0.38               0.35    None      0.39
# RandomForestClassifier             0.42               0.34    None      0.43
# RidgeClassifier                    0.34               0.33    None      0.29
# RidgeClassifierCV                  0.34               0.33    None      0.29
# SGDClassifier                      0.36               0.32    None      0.36
# BaggingClassifier                  0.39               0.32    None      0.40
# GaussianNB                         0.27               0.29    None      0.25
# KNeighborsClassifier               0.36               0.28    None      0.36
# DecisionTreeClassifier             0.32               0.28    None      0.34
# PassiveAggressiveClassifier        0.27               0.28    None      0.24
# Perceptron                         0.29               0.27    None      0.31
# NearestCentroid                    0.36               0.27    None      0.37
# ExtraTreeClassifier                0.29               0.26    None      0.32
# QuadraticDiscriminantAnalysis      0.10               0.16    None      0.07
# DummyClassifier                    0.25               0.14    None      0.10
#
#                                macro_averaged_mean_absolute_error  Time Taken
# Model
# XGBClassifier                                                1.11        2.60
# LGBMClassifier                                               1.09        2.37
# LogisticRegression                                           1.13        2.02
# LinearDiscriminantAnalysis                                   1.09        0.57
# AdaBoostClassifier                                           1.16        7.36
# CalibratedClassifierCV                                       1.18       12.11
# ExtraTreesClassifier                                         1.16       16.56
# BernoulliNB                                                  1.21        0.38
# RandomForestClassifier                                       1.16       25.10
# RidgeClassifier                                              1.34        0.38
# RidgeClassifierCV                                            1.34        0.53
# SGDClassifier                                                1.30        3.29
# BaggingClassifier                                            1.24       13.29
# GaussianNB                                                   1.24        0.47
# KNeighborsClassifier                                         1.42        3.36
# DecisionTreeClassifier                                       1.39        2.14
# PassiveAggressiveClassifier                                  1.48        0.90
# Perceptron                                                   1.70        0.86
# NearestCentroid                                              1.58        0.33
# ExtraTreeClassifier                                          1.45        0.48
# QuadraticDiscriminantAnalysis                                1.69        0.63
# DummyClassifier                                              3.00        0.31

# %%
reg = LazyRegressor(
    random_state=42, custom_metric=reg_macro_averaged_mean_absolute_error
)
reg_models, predictions = reg.fit(X_train, X_val, y_train, y_val)
reg_models
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
#  97%|█████████▋| 33/34 [01:42<00:00,  1.41it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003036 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2751
# [LightGBM] [Info] Number of data points in the train set: 53935, number of used features: 31
# [LightGBM] [Info] Start training from score 3.000000
# 100%|██████████| 34/34 [01:43<00:00,  3.04s/it]
#                                Adjusted R-Squared  R-Squared  RMSE  \
# Model
# PoissonRegressor                            -0.09      -0.09  1.21
# LGBMRegressor                               -0.11      -0.11  1.22
# HistGradientBoostingRegressor               -0.12      -0.12  1.22
# GradientBoostingRegressor                   -0.12      -0.12  1.22
# HuberRegressor                              -0.17      -0.17  1.25
# XGBRegressor                                -0.18      -0.18  1.25
# LinearSVR                                   -0.18      -0.18  1.26
# TransformedTargetRegressor                  -0.19      -0.19  1.26
# LinearRegression                            -0.19      -0.19  1.26
# Ridge                                       -0.19      -0.19  1.26
# RidgeCV                                     -0.19      -0.19  1.26
# BayesianRidge                               -0.19      -0.19  1.26
# LassoCV                                     -0.20      -0.20  1.27
# ElasticNetCV                                -0.20      -0.20  1.27
# LassoLarsCV                                 -0.24      -0.24  1.29
# LarsCV                                      -0.24      -0.24  1.29
# MLPRegressor                                -0.24      -0.24  1.29
# Lars                                        -0.24      -0.24  1.29
# LassoLarsIC                                 -0.25      -0.25  1.29
# SGDRegressor                                -0.27      -0.26  1.30
# BaggingRegressor                            -0.30      -0.30  1.32
# TweedieRegressor                            -0.33      -0.33  1.33
# KNeighborsRegressor                         -0.43      -0.42  1.38
# OrthogonalMatchingPursuitCV                 -0.53      -0.53  1.43
# RANSACRegressor                             -0.58      -0.58  1.46
# AdaBoostRegressor                           -0.70      -0.70  1.51
# PassiveAggressiveRegressor                  -0.93      -0.93  1.61
# OrthogonalMatchingPursuit                   -1.11      -1.11  1.68
# ElasticNet                                  -1.29      -1.29  1.75
# DecisionTreeRegressor                       -1.40      -1.40  1.79
# ExtraTreeRegressor                          -1.47      -1.47  1.82
# LassoLars                                   -1.82      -1.82  1.94
# DummyRegressor                              -1.82      -1.82  1.94
# Lasso                                       -1.82      -1.82  1.94
#
#                                Time Taken  \
# Model
# PoissonRegressor                     0.37
# LGBMRegressor                        0.69
# HistGradientBoostingRegressor        1.51
# GradientBoostingRegressor           21.77
# HuberRegressor                       1.54
# XGBRegressor                         0.70
# LinearSVR                            9.32
# TransformedTargetRegressor           0.32
# LinearRegression                     0.30
# Ridge                                0.26
# RidgeCV                              0.42
# BayesianRidge                        0.34
# LassoCV                              1.12
# ElasticNetCV                         3.33
# LassoLarsCV                          0.61
# LarsCV                               0.65
# MLPRegressor                        30.86
# Lars                                 0.29
# LassoLarsIC                          0.34
# SGDRegressor                         0.45
# BaggingRegressor                    12.87
# TweedieRegressor                     0.35
# KNeighborsRegressor                  3.42
# OrthogonalMatchingPursuitCV          0.43
# RANSACRegressor                      0.80
# AdaBoostRegressor                    5.39
# PassiveAggressiveRegressor           0.34
# OrthogonalMatchingPursuit            0.30
# ElasticNet                           0.30
# DecisionTreeRegressor                1.87
# ExtraTreeRegressor                   0.74
# LassoLars                            0.27
# DummyRegressor                       0.23
# Lasso                                0.30
#
#                                reg_macro_averaged_mean_absolute_error
# Model
# PoissonRegressor                                                 1.30
# LGBMRegressor                                                    1.33
# HistGradientBoostingRegressor                                    1.35
# GradientBoostingRegressor                                        1.33
# HuberRegressor                                                   1.35
# XGBRegressor                                                     1.38
# LinearSVR                                                        1.36
# TransformedTargetRegressor                                        NaN
# LinearRegression                                                  NaN
# Ridge                                                             NaN
# RidgeCV                                                           NaN
# BayesianRidge                                                    1.34
# LassoCV                                                          1.34
# ElasticNetCV                                                     1.34
# LassoLarsCV                                                      1.37
# LarsCV                                                           1.37
# MLPRegressor                                                     1.42
# Lars                                                             1.37
# LassoLarsIC                                                      1.36
# SGDRegressor                                                     1.37
# BaggingRegressor                                                 1.42
# TweedieRegressor                                                 1.38
# KNeighborsRegressor                                               NaN
# OrthogonalMatchingPursuitCV                                      1.48
# RANSACRegressor                                                   NaN
# AdaBoostRegressor                                                 NaN
# PassiveAggressiveRegressor                                       1.41
# OrthogonalMatchingPursuit                                        1.70
# ElasticNet                                                        NaN
# DecisionTreeRegressor                                            1.72
# ExtraTreeRegressor                                               1.73
# LassoLars                                                         NaN
# DummyRegressor                                                    NaN
# Lasso                                                             NaN

# %% [markdown]
# ## Outcome

# %% [markdown]
# For ordered classification, simple multi classification approach is more suitable than regression. LGBMClassifier has the lowest macro-averaged mean absolute error and is chosen for further tuning to predict loan grades.
