# %% [markdown]
# # Tuning of Loan Grade Prediction Model

# %% [markdown]
# First, all the necessary libraries are imported.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from imblearn.metrics import macro_averaged_mean_absolute_error
from sklearn.pipeline import Pipeline
from lightgbm import LGBMClassifier
import lightgbm as lgbm
import optuna
from optuna import Trial
import joblib
from helper_functions.ml_data_prep import (
    X_y_spilt,
    stratified_sample,
)
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# Data is loaded and appropriately splited.

# %%
drop_cols = ["sub_grade", "int_rate", "sub_grade_enc", "grade"]
# Subsample training and validation if wanting to check the code
# X_train, y_train = (
#     pd.read_pickle("./data/data_train_mod2.pkl")
#     .pipe(stratified_sample, frac=0.1, col="sub_grade")
#     .drop(columns=drop_cols)
#     .pipe(X_y_spilt, target="grade_enc")
# )
# X_val, y_val = (
#     pd.read_pickle("./data/data_val_mod2.pkl")
#     .pipe(stratified_sample, frac=0.1, col="sub_grade")
#     .drop(columns=drop_cols)
#     .pipe(X_y_spilt, target="grade_enc")
# )
X_train, y_train = (
    pd.read_pickle("./data/data_train_mod2.pkl")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="grade_enc")
)
X_val, y_val = (
    pd.read_pickle("./data/data_val_mod2.pkl")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="grade_enc")
)
print(f"Number of training instances {X_train.shape[0]}")
print(f"Number of validation instances {X_val.shape[0]}")
print("Target counts for validation:")
print(y_val.value_counts())
X_train.dtypes
# Out:
# Number of training instances 1765426
# Number of validation instances 238636
# Target counts for validation:
# grade_enc
# 1    70728
# 2    64259
# 0    59785
# 3    33921
# 4     8040
# 5     1605
# 6      298
# Name: count, dtype: int64
# loan_amnt                  float64
# term                      category
# home_ownership            category
# verification_status       category
# purpose                   category
# dti                        float64
# inq_last_6mths             float64
# mths_since_last_record     float64
# application_type          category
# open_il_12m                float64
# all_util                   float64
# total_rev_hi_lim           float64
# inq_last_12m               float64
# acc_open_past_24mths       float64
# bc_open_to_buy             float64
# bc_util                    float64
# mo_sin_old_il_acct         float64
# mo_sin_old_rev_tl_op       float64
# mort_acc                   float64
# mths_since_recent_inq      float64
# num_actv_rev_tl            float64
# num_tl_op_past_12m         float64
# pct_tl_nvr_dlq             float64
# tot_hi_cred_lim            float64
# fico                       float64
# dtype: object

# %%
selector_model = LGBMClassifier(verbose=-1, random_state=42)
selector_model.fit(X_train, y_train)
lgbm.plot_importance(selector_model, height=0.8, grid=False, ignore_zero=False)
plt.title("Feature Importance for Loan Grade Prediction Model")
plt.show()

# %% [markdown]
# Necessary subfunctions for Optuna objective function defined.

# %%
def instantiate_feature_selector(trial: Trial) -> SelectFromModel:
    params = {
        "threshold": -np.inf,
        "prefit": True,
        "max_features": trial.suggest_int("max_features", 3, 23),
    }
    feature_selector = SelectFromModel(selector_model, **params).set_output(
        transform="pandas"
    )
    return feature_selector


def instantiate_lightgbm(trial: Trial) -> LGBMClassifier:
    params = {
        "verbosity": -1,
        "n_jobs": 4,
        "random_state": 42,
        "objective": "multiclass",
        "num_class": 7,
        "n_estimators": 200,
        "boosting_type": "gbdt",
        "metric": "custom",
        "early_stopping_rounds": 10,
        "class_weight": "balanced",
        "reg_lambda": trial.suggest_float("reg_lambda", 1e-4, 10, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 1e-4, 10, log=True),
        "subsample": trial.suggest_float("subsample", 0.4, 1.0, step=0.1),
        "colsample_bytree": trial.suggest_float(
            "colsample_bytree", 0.4, 1.0, step=0.1
        ),
        "max_depth": trial.suggest_int("max_depth", 2, 31),
        "min_child_weight": trial.suggest_float(
            "min_child_weight", 0.01, 1000
        ),
        "num_leaves": trial.suggest_int("num_leaves", 7, 63),
    }
    return LGBMClassifier(**params)


def instantiate_model(trial: Trial) -> Pipeline:
    pipeline = Pipeline([
        ("selector", instantiate_feature_selector(trial)),
        ("estimator", instantiate_lightgbm(trial)),
    ])
    return pipeline

# %% [markdown]
# Optuna study defined and run.

# %%
def macro_avg_mae(y_true, y_pred):
    higher_is_better = False
    y_pred = np.argmax(y_pred, axis=1)
    macro_avg_mae = macro_averaged_mean_absolute_error(y_true, y_pred)
    return "macro_avg_mae", macro_avg_mae, higher_is_better


def objective(trial: Trial) -> float:
    model = instantiate_model(trial)
    prepro = model[:-1].fit(X_train)
    X_val_prepro = prepro.transform(X_val)
    pruning_callback = optuna.integration.LightGBMPruningCallback(
        trial, "macro_avg_mae"
    )
    model.fit(
        X_train,
        y_train,
        estimator__eval_set=[(X_val_prepro, y_val)],
        estimator__eval_metric=[macro_avg_mae],
        estimator__callbacks=[pruning_callback],
    )
    trial.set_user_attr("n_estimators", model[-1].best_iteration_ + 1)
    y_pred = model.predict(X_val)
    value = macro_averaged_mean_absolute_error(y_val, y_pred)
    return value


pruner = optuna.pruners.MedianPruner(n_warmup_steps=10, n_min_trials=5)
study = optuna.create_study(
    study_name="grade_model_hypertune",
    storage="sqlite:///grade_model_hypertune.db",
    load_if_exists=True,
    pruner=pruner,
    direction="minimize",
)
study.optimize(objective, n_trials=100)
best_trial = study.best_trial
n_estimators = best_trial.user_attrs["n_estimators"]
print("Best macro-averaged MAE value:", study.best_value)
print("Best parameters:")
display(study.best_params)
# Out:
# [I 2024-02-04 19:52:07,683] A new study created in RDB with name: grade_model_hypertune
# [I 2024-02-04 19:52:56,510] Trial 0 finished with value: 1.1313836329225906 and parameters: {'max_features': 14, 'reg_lambda': 0.0016553621458699607, 'reg_alpha': 0.002329738592082477, 'subsample': 0.4, 'colsample_bytree': 0.8, 'max_depth': 8, 'min_child_weight': 717.7636288835201, 'num_leaves': 32}. Best is trial 0 with value: 1.1313836329225906.
# [I 2024-02-04 19:54:09,233] Trial 1 finished with value: 1.1052463007317617 and parameters: {'max_features': 14, 'reg_lambda': 0.07148689169224762, 'reg_alpha': 1.1874007448774457, 'subsample': 1.0, 'colsample_bytree': 0.5, 'max_depth': 15, 'min_child_weight': 817.1378778047863, 'num_leaves': 63}. Best is trial 1 with value: 1.1052463007317617.
# [I 2024-02-04 19:54:48,006] Trial 2 finished with value: 1.5028413505950469 and parameters: {'max_features': 4, 'reg_lambda': 0.029221515378710722, 'reg_alpha': 0.0005347090956638672, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.6000000000000001, 'max_depth': 20, 'min_child_weight': 864.3722720282982, 'num_leaves': 23}. Best is trial 1 with value: 1.1052463007317617.
# [I 2024-02-04 19:55:01,412] Trial 3 finished with value: 1.531370908251471 and parameters: {'max_features': 3, 'reg_lambda': 0.012533799748404965, 'reg_alpha': 0.06907084552742233, 'subsample': 0.5, 'colsample_bytree': 0.8, 'max_depth': 25, 'min_child_weight': 321.3508184742762, 'num_leaves': 28}. Best is trial 1 with value: 1.1052463007317617.
# [I 2024-02-04 19:56:11,058] Trial 4 finished with value: 1.1125947540885182 and parameters: {'max_features': 17, 'reg_lambda': 0.00039684801040550317, 'reg_alpha': 0.6459228230572236, 'subsample': 0.9, 'colsample_bytree': 0.9, 'max_depth': 7, 'min_child_weight': 276.30137812556745, 'num_leaves': 19}. Best is trial 1 with value: 1.1052463007317617.
# [I 2024-02-04 19:56:18,347] Trial 5 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 19
pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:11:08,919] Trial 73 pruned. Trial was pruned at iteration 15.
# [I 2024-02-04 20:11:14,967] Trial 74 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:11:24,594] Trial 75 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:11:31,238] Trial 76 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:12:44,509] Trial 77 finished with value: 1.1099808458438774 and parameters: {'max_features': 14, 'reg_lambda': 0.0023598240002772122, 'reg_alpha': 0.005170821814834022, 'subsample': 0.7000000000000001, 'colsample_bytree': 0.7000000000000001, 'max_depth': 19, 'min_child_weight': 214.47646561386745, 'num_leaves': 58}. Best is trial 25 with value: 1.0738484284635692.
# [I 2024-02-04 20:13:25,349] Trial 78 pruned. Trial was pruned at iteration 60.
# [I 2024-02-04 20:13:32,132] Trial 79 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:14:19,911] Trial 80 finished with value: 1.1194091926974672 and parameters: {'max_features': 14, 'reg_lambda': 0.0008309348696596577, 'reg_alpha': 0.00040051151066791316, 'subsample': 0.8, 'colsample_bytree': 0.7000000000000001, 'max_depth': 17, 'min_child_weight': 204.30766989757745, 'num_leaves': 54}. Best is trial 25 with value: 1.0738484284635692.
# [I 2024-02-04 20:15:00,402] Trial 81 pruned. Trial was pruned at iteration 59.
# [I 2024-02-04 20:15:08,836] Trial 82 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:15:18,845] Trial 83 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:15:27,941] Trial 84 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:15:36,681] Trial 85 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:15:46,151] Trial 86 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:15:54,183] Trial 87 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:16:03,691] Trial 88 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:16:11,731] Trial 89 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:03,938] Trial 90 pruned. Trial was pruned at iteration 63.
# [I 2024-02-04 20:17:11,252] Trial 91 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:24,581] Trial 92 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:32,797] Trial 93 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:41,715] Trial 94 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:48,349] Trial 95 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:17:57,117] Trial 96 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:18:04,113] Trial 97 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:18:12,543] Trial 98 pruned. Trial was pruned at iteration 10.
# [I 2024-02-04 20:18:20,343] Trial 99 pruned. Trial was pruned at iteration 10.
# Best macro-averaged MAE value: 1.0738484284635692
# Best parameters:
# {'max_features': 17,
#  'reg_lambda': 0.0038071919424446836,
#  'reg_alpha': 0.000790754976515777,
#  'subsample': 0.5,
#  'colsample_bytree': 1.0,
#  'max_depth': 10,
#  'min_child_weight': 405.8769103685436,
#  'num_leaves': 63}

# %% [markdown]
# The final tuned model obtained.

# %%
grade_model = instantiate_model(best_trial)
grade_model.set_params(
    estimator__n_estimators=n_estimators,
    estimator__early_stopping_rounds=None,
    estimator__callbacks=None,
)
grade_model
# Out:
# Pipeline(steps=[('selector',
#                  SelectFromModel(estimator=LGBMClassifier(random_state=42,
#                                                           verbose=-1),
#                                  max_features=18, prefit=True,
#                                  threshold=-inf)),
#                 ('estimator',
#                  LGBMClassifier(callbacks=None, class_weight='balanced',
#                                 colsample_bytree=0.7000000000000001,
#                                 early_stopping_rounds=None, max_depth=31,
#                                 metric='custom',
#                                 min_child_weight=964.6768970585872,
#                                 n_estimators=134, n_jobs=4, num_class=7,
#                                 num_leaves=62, objective='multiclass',
#                                 random_state=42,
#                                 reg_alpha=0.00030463628754270335,
#                                 reg_lambda=0.1685738821836936, verbosity=-1))])

# %% [markdown]
# Model fitted to the whole training data (training and validation sets) and dumped for later use.

# %%
X_train, y_train = (
    pd.concat([
        pd.read_pickle("./data/data_train_mod2.pkl"),
        pd.read_pickle("./data/data_val_mod2.pkl"),
    ])
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="grade_enc")
)
grade_model.fit(X_train, y_train)
joblib.dump(grade_model, "./tuned_models/grade_model.joblib")
# Out:
# ['./tuned_models/grade_model.joblib']
