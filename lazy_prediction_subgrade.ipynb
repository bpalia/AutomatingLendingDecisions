# %% [markdown]
# # Lazy Prediction of Loan Subgrade Model

# %% [markdown]
# First, all the necessary libraries are imported.

# %%
import lazypredict
import pandas as pd
from imblearn.metrics import macro_averaged_mean_absolute_error
from helper_functions.custom_model import (
    reg_macro_averaged_mean_absolute_error,
)
from lazypredict.Supervised import LazyClassifier, LazyRegressor
from helper_functions.ml_data_prep import (
    stratified_sample,
    X_y_spilt,
)

# %% [markdown]
# Computationally expensive and unable to execute classifiers and regressors are removed.

# %%
classifiers = lazypredict.Supervised.CLASSIFIERS
classifiers_to_remove = [
    "StackingClassifier",
    "CategoricalNB",
    "LabelPropagation",
    "LabelSpreading",
    "NuSVC",
    "SVC",
    "LinearSVC",
]
for model, _ in classifiers[:]:
    if model in classifiers_to_remove:
        classifiers.remove((model, _))

# %%
regressors = lazypredict.Supervised.REGRESSORS
regressors_to_remove = [
    "GammaRegressor",
    "QuantileRegressor",
    "GaussianProcessRegressor",
    "KernelRidge",
    "NuSVR",
    "SVR",
    "RandomForestRegressor",
    "ExtraTreesRegressor",
]
for model, _ in regressors[:]:
    if model in regressors_to_remove:
        regressors.remove((model, _))

# %% [markdown]
# Data loaded and splited. Training performed on balanced data. Only 25% of validation data is used.

# %%
drop_cols = ["int_rate", "grade_enc", "sub_grade"]
X_train, y_train = (
    pd.read_pickle("./data/data_train_balanced_mod2.pkl")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="sub_grade_enc")
)
X_val, y_val = (
    pd.read_pickle("./data/data_val_mod2.pkl")
    .pipe(stratified_sample, frac=0.25, col="sub_grade")
    .drop(columns=drop_cols)
    .pipe(X_y_spilt, target="sub_grade_enc")
)
print(f"Number of training instances {X_train.shape[0]}")
print(f"Number of validation instances {X_val.shape[0]}")
print("Target counts for validation:")
print(y_val.value_counts())
# Out:
# Number of training instances 53935
# Number of validation instances 59660
# Target counts for validation:
# sub_grade_enc
# 9     3794
# 5     3682
# 6     3668
# 8     3617
# 10    3593
# 3     3478
# 11    3236
# 12    3220
# 2     3136
# 13    3132
# 7     2921
# 4     2886
# 14    2885
# 1     2760
# 0     2686
# 15    1954
# 16    1850
# 17    1704
# 18    1532
# 19    1440
# 24     530
# 22     457
# 23     396
# 21     343
# 20     284
# 25     220
# 30      64
# 26      54
# 27      48
# 29      42
# 28      38
# 31       4
# 32       3
# 33       2
# 34       1
# Name: count, dtype: int64

# %% [markdown]
# A number of different classifiers and regressors are trained and evaluated. Macro averaged mean absolute error is used to compare classifiers and regressors. This metric accounts for class order.

# %%
clf = LazyClassifier(
    random_state=42, custom_metric=macro_averaged_mean_absolute_error
)
clf_models, _ = clf.fit(X_train, X_val, y_train, y_val)
clf_models
# Out:
#   0%|          | 0/22 [00:00<?, ?it/s]
#  95%|█████████▌| 21/22 [02:38<00:07,  7.40s/it]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.003214 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2765
# [LightGBM] [Info] Number of data points in the train set: 53935, number of used features: 38
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# [LightGBM] [Info] Start training from score -3.555348
# 100%|██████████| 22/22 [02:48<00:00,  7.66s/it]
#                                Accuracy  Balanced Accuracy ROC AUC  F1 Score  \
# Model
# LGBMClassifier                     0.24               0.25    None      0.24
# LogisticRegression                 0.24               0.25    None      0.23
# RidgeClassifier                    0.24               0.25    None      0.21
# RidgeClassifierCV                  0.24               0.25    None      0.21
# CalibratedClassifierCV             0.24               0.25    None      0.23
# BernoulliNB                        0.23               0.25    None      0.21
# ExtraTreeClassifier                0.21               0.24    None      0.21
# RandomForestClassifier             0.24               0.24    None      0.23
# PassiveAggressiveClassifier        0.21               0.23    None      0.18
# XGBClassifier                      0.24               0.23    None      0.24
# GaussianNB                         0.22               0.23    None      0.15
# Perceptron                         0.22               0.23    None      0.19
# QuadraticDiscriminantAnalysis      0.20               0.22    None      0.14
# BaggingClassifier                  0.23               0.22    None      0.22
# ExtraTreesClassifier               0.23               0.21    None      0.23
# SGDClassifier                      0.22               0.21    None      0.18
# DecisionTreeClassifier             0.22               0.20    None      0.22
# AdaBoostClassifier                 0.21               0.20    None      0.07
# NearestCentroid                    0.17               0.18    None      0.16
# KNeighborsClassifier               0.15               0.14    None      0.14
# LinearDiscriminantAnalysis         0.09               0.09    None      0.08
# DummyClassifier                    0.05               0.03    None      0.00
#
#                                macro_averaged_mean_absolute_error  Time Taken
# Model
# LGBMClassifier                                               1.43        9.96
# LogisticRegression                                           1.49        5.23
# RidgeClassifier                                              1.56        0.43
# RidgeClassifierCV                                            1.56        0.71
# CalibratedClassifierCV                                       1.45       33.52
# BernoulliNB                                                  1.54        0.48
# ExtraTreeClassifier                                          1.61        0.57
# RandomForestClassifier                                       1.42       32.12
# PassiveAggressiveClassifier                                  1.54        3.29
# XGBClassifier                                                1.51        9.34
# GaussianNB                                                   1.46        1.16
# Perceptron                                                   1.53        2.87
# QuadraticDiscriminantAnalysis                                1.46        1.85
# BaggingClassifier                                            1.58       17.48
# ExtraTreesClassifier                                         1.52       20.51
# SGDClassifier                                                1.63        7.84
# DecisionTreeClassifier                                       1.58        2.86
# AdaBoostClassifier                                           1.89       13.29
# NearestCentroid                                              5.94        0.35
# KNeighborsClassifier                                         5.17        3.37
# LinearDiscriminantAnalysis                                   6.25        0.66
# DummyClassifier                                             17.00        0.31

# %%
reg = LazyRegressor(
    random_state=42, custom_metric=reg_macro_averaged_mean_absolute_error
)
reg_models, predictions = reg.fit(X_train, X_val, y_train, y_val)
reg_models
# Out:
#   0%|          | 0/34 [00:00<?, ?it/s]
#  97%|█████████▋| 33/34 [01:54<00:00,  1.41it/s]
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.004082 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 2765
# [LightGBM] [Info] Number of data points in the train set: 53935, number of used features: 38
# [LightGBM] [Info] Start training from score 17.000000
# 100%|██████████| 34/34 [01:54<00:00,  3.37s/it]
#                                Adjusted R-Squared  R-Squared  RMSE  \
# Model
# LassoCV                                      0.95       0.95  1.38
# LassoLarsIC                                  0.95       0.95  1.38
# RidgeCV                                      0.94       0.95  1.38
# Ridge                                        0.94       0.95  1.38
# BayesianRidge                                0.94       0.95  1.38
# Lars                                         0.94       0.95  1.38
# LinearRegression                             0.94       0.95  1.38
# TransformedTargetRegressor                   0.94       0.95  1.38
# RANSACRegressor                              0.94       0.94  1.38
# HistGradientBoostingRegressor                0.94       0.94  1.38
# LGBMRegressor                                0.94       0.94  1.38
# SGDRegressor                                 0.94       0.94  1.38
# HuberRegressor                               0.94       0.94  1.38
# LinearSVR                                    0.94       0.94  1.39
# GradientBoostingRegressor                    0.94       0.94  1.39
# XGBRegressor                                 0.94       0.94  1.42
# MLPRegressor                                 0.94       0.94  1.43
# BaggingRegressor                             0.94       0.94  1.45
# AdaBoostRegressor                            0.91       0.91  1.76
# DecisionTreeRegressor                        0.89       0.89  1.94
# ExtraTreeRegressor                           0.89       0.89  1.97
# PassiveAggressiveRegressor                   0.85       0.85  2.24
# PoissonRegressor                             0.70       0.70  3.21
# LarsCV                                       0.68       0.68  3.35
# LassoLarsCV                                  0.68       0.68  3.35
# ElasticNetCV                                 0.63       0.63  3.59
# KNeighborsRegressor                          0.21       0.21  5.22
# TweedieRegressor                            -0.07      -0.07  6.08
# ElasticNet                                  -0.12      -0.12  6.22
# Lasso                                       -0.18      -0.18  6.39
# LassoLars                                   -0.18      -0.18  6.39
# OrthogonalMatchingPursuitCV                 -0.48      -0.48  7.16
# OrthogonalMatchingPursuit                   -0.97      -0.96  8.25
# DummyRegressor                              -1.78      -1.77  9.80
#
#                                Time Taken  \
# Model
# LassoCV                              3.35
# LassoLarsIC                          0.48
# RidgeCV                              0.47
# Ridge                                0.30
# BayesianRidge                        0.39
# Lars                                 0.33
# LinearRegression                     0.41
# TransformedTargetRegressor           0.37
# RANSACRegressor                      0.41
# HistGradientBoostingRegressor        1.28
# LGBMRegressor                        0.60
# SGDRegressor                         0.40
# HuberRegressor                       1.75
# LinearSVR                            8.02
# GradientBoostingRegressor           22.62
# XGBRegressor                         0.61
# MLPRegressor                        34.86
# BaggingRegressor                    14.01
# AdaBoostRegressor                   11.19
# DecisionTreeRegressor                2.04
# ExtraTreeRegressor                   0.83
# PassiveAggressiveRegressor           0.36
# PoissonRegressor                     0.58
# LarsCV                               0.72
# LassoLarsCV                          0.79
# ElasticNetCV                         0.86
# KNeighborsRegressor                  3.66
# TweedieRegressor                     0.37
# ElasticNet                           0.34
# Lasso                                0.35
# LassoLars                            0.43
# OrthogonalMatchingPursuitCV          0.49
# OrthogonalMatchingPursuit            0.30
# DummyRegressor                       0.25
#
#                                reg_macro_averaged_mean_absolute_error
# Model
# LassoCV                                                           NaN
# LassoLarsIC                                                       NaN
# RidgeCV                                                           NaN
# Ridge                                                             NaN
# BayesianRidge                                                     NaN
# Lars                                                              NaN
# LinearRegression                                                  NaN
# TransformedTargetRegressor                                        NaN
# RANSACRegressor                                                   NaN
# HistGradientBoostingRegressor                                     NaN
# LGBMRegressor                                                     NaN
# SGDRegressor                                                      NaN
# HuberRegressor                                                    NaN
# LinearSVR                                                         NaN
# GradientBoostingRegressor                                         NaN
# XGBRegressor                                                      NaN
# MLPRegressor                                                      NaN
# BaggingRegressor                                                  NaN
# AdaBoostRegressor                                                 NaN
# DecisionTreeRegressor                                            1.60
# ExtraTreeRegressor                                               1.61
# PassiveAggressiveRegressor                                       2.03
# PoissonRegressor                                                  NaN
# LarsCV                                                            NaN
# LassoLarsCV                                                       NaN
# ElasticNetCV                                                      NaN
# KNeighborsRegressor                                               NaN
# TweedieRegressor                                                  NaN
# ElasticNet                                                        NaN
# Lasso                                                             NaN
# LassoLars                                                         NaN
# OrthogonalMatchingPursuitCV                                      7.52
# OrthogonalMatchingPursuit                                        8.65
# DummyRegressor                                                    NaN

# %% [markdown]
# ## Outcome

# %% [markdown]
# For ordered classification, simple multi classification approach is more suitable than regression. LGBMClassifier has the lowest macro-averaged mean absolute error and is chosen for further tuning to predict loan subgrades. With many classes, regression models quite often do not predict minority classes at all.
